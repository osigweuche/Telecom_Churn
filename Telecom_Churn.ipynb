# %% [markdown]
# ### Exploratory Data Analysis (EDA) - Telecom Churn

# %%
# Import libraries

# For Data Analysis
import numpy as np
import pandas as pd

#For Data Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load your Dataset

df = pd.read_csv("C:\\Users\\personal\\Documents\\Urch_Training\\Data Analyst\\10Alytics\\telecom_churn.csv")

# %%
# Data Dimensionality
# Data Dimensionality - number of rows, number of columns in the dataset
# columns are regarded as FEATURES

df.shape
# Out:
# (3333, 20)

# %%
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
# Extract the columns
# Check for space and remove to avoid errors

df.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
#Check information of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3333 non-null   float64
#  7   Total day calls         3333 non-null   int64
#  8   Total day charge        3333 non-null   float64
#  9   Total eve minutes       3333 non-null   float64
#  10  Total eve calls         3333 non-null   int64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3333 non-null   int64
# ...

# %%
# Converting Churn Feature which is Boolean into an integer

df["Churn"] = df["Churn"].astype("int64")

# %%
# Statistical run down of the dataset

df.describe()
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# ...

# %%
# Objec and Boolean data type for describe
df.describe(include=["object", "bool"])
# Out:
#        State International plan Voice mail plan
# count   3333               3333            3333
# unique    51                  2               2
# top       WV                 No              No
# freq     106               3010            2411

# %%
# Looking at the distribution of Churn - unbalanced dataset

df["Churn"].value_counts()
# Out:
# 0    2850
# 1     483
# Name: Churn, dtype: int64

# %%
# 2850 user out 3333 are false customers while 483 are true customers

df["Churn"].value_counts(normalize=True)
# Out:
# 0    0.855086
# 1    0.144914
# Name: Churn, dtype: float64

# %%
round(df["Churn"].value_counts(normalize=True),2)
# Out:
# 0    0.86
# 1    0.14
# Name: Churn, dtype: float64

# %% [markdown]
# ### Sorting
# DataFrame can be sorted by the value of one variable in the dataset

# %%
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
# Sorting based on one column
df.sort_values(by="Number vmail messages", ascending=False).head()
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 845     FL             144        415                 No             Yes
# 2887    OR             134        415                 No             Yes
# 2716    WV             137        510                 No             Yes
# 1596    AR              63        510                 No             Yes
# 268     MO              64        510                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 845                      51              283.9               98
# 2887                     50              208.8              130
# 2716                     50              186.5               94
# 1596                     49              214.9               86
# 268                      48               94.4              104
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# ...

# %%
# Sorting based on one column or more columns
df.sort_values(by=["Churn", "Number vmail messages"], ascending=False).head()
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 277     SD             144        408                 No             Yes
# 1269    FL              55        510                 No             Yes
# 1454    UT             133        408                 No             Yes
# 3246    NC              77        408                Yes             Yes
# 115     ME              36        510                Yes             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 277                      48              189.8               96
# 1269                     45              130.5              114
# 1454                     44              174.0               80
# 3246                     44              103.2              117
# 115                      42              196.8               89
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# ...

# %%
# Mean of numerical feature for Churn users

df[df["Churn"]==1].mean()
# Out:
# Account length            102.664596
# Area code                 437.817805
# Number vmail messages       5.115942
# Total day minutes         206.914079
# Total day calls           101.335404
# Total day charge           35.175921
# Total eve minutes         212.410145
# Total eve calls           100.561077
# Total eve charge           18.054969
# Total night minutes       205.231677
# Total night calls         100.399586
# Total night charge          9.235528
# Total intl minutes         10.700000
# Total intl calls            4.163561
# Total intl charge           2.889545
# Customer service calls      2.229814
# Churn                       1.000000
# dtype: float64

# %%
df[df["Churn"]==0].mean()
# Out:
# Account length            100.793684
# Area code                 437.074737
# Number vmail messages       8.604561
# Total day minutes         175.175754
# Total day calls           100.283158
# Total day charge           29.780421
# Total eve minutes         199.043298
# Total eve calls           100.038596
# Total eve charge           16.918909
# Total night minutes       200.133193
# Total night calls         100.058246
# Total night charge          9.006074
# Total intl minutes         10.158877
# Total intl calls            4.532982
# Total intl charge           2.743404
# Customer service calls      1.449825
# Churn                       0.000000
# dtype: float64

# %%
df[df["Voice mail plan"]=="Yes"].mean()
# Out:
# Account length            101.252711
# Area code                 437.131236
# Number vmail messages      29.277657
# Total day minutes         179.626790
# Total day calls           100.075922
# Total day charge           30.537072
# Total eve minutes         202.746963
# Total eve calls            99.906725
# Total eve charge           17.233796
# Total night minutes       201.369089
# Total night calls         100.599783
# Total night charge          9.061638
# Total intl minutes         10.231345
# Total intl calls            4.509761
# Total intl charge           2.763026
# Customer service calls      1.524946
# Churn                       0.086768
# dtype: float64

# %%
# Example: find out states that with w

df[df["State"].apply(lambda state: state[0] == "W")].head()
# Out:
#    State  Account length  Area code International plan Voice mail plan  \
# 9     WV             141        415                Yes             Yes
# 26    WY              57        408                 No             Yes
# 44    WI              64        510                 No              No
# 49    WY              97        415                 No             Yes
# 54    WY              87        415                 No              No
#
#     Number vmail messages  Total day minutes  Total day calls  \
# 9                      37              258.6               84
# 26                     39              213.0              115
# 44                      0              154.0               67
# 49                     24              133.2              135
# 54                      0              151.0               83
#
#     Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 9              43.96              222.0              111             18.87
# ...

# %%
# Crosstab
# It allows you to create a summary table

pd.crosstab(df["Churn"], df["International plan"])
# Out:
# International plan    No  Yes
# Churn
# 0                   2664  186
# 1                    346  137

# %%
pd.crosstab(df["Churn"], df["State"])
# Out:
# State  AK  AL  AR  AZ  CA  CO  CT  DC  DE  FL  ...  SD  TN  TX  UT  VA  VT  \
# Churn                                          ...
# 0      49  72  44  60  25  57  62  49  52  55  ...  52  48  54  62  72  65
# 1       3   8  11   4   9   9  12   5   9   8  ...   8   5  18  10   5   8
#
# State  WA  WI  WV  WY
# Churn
# 0      52  71  96  68
# 1      14   7  10   9
#
# [2 rows x 51 columns]

# %%
pd.crosstab(df["Churn"], df["International plan"], normalize=True)
# Out:
# International plan       No       Yes
# Churn
# 0                   0.79928  0.055806
# 1                   0.10381  0.041104

# %%
# Pivot Table

df.pivot_table(["Total day calls", "Total eve calls", "Total night calls"], ["State"], aggfunc="mean")
# Out:
#        Total day calls  Total eve calls  Total night calls
# State
# AK           95.269231        96.576923          97.346154
# AL           99.100000        98.462500          98.612500
# AR          102.145455        97.836364          99.054545
# AZ          100.109375       102.406250          99.984375
# CA          104.500000       103.088235          99.205882
# CO           95.121212        98.166667          97.060606
# CT           98.432432        99.121622         102.283784
# DC          100.166667       101.981481          97.666667
# DE           98.639344        97.360656         101.213115
# FL          101.000000       108.920635         100.333333
# GA          103.055556       103.888889         105.425926
# HI          102.811321        98.849057          99.150943
# IA          103.045455        99.545455         100.136364
# ID          106.219178       100.054795         100.424658
# IL          101.689655       100.810345          99.224138
# ...

# %%
df.pivot_table(["Total day calls", "Total eve calls", "Total night calls"], ["Area code"], aggfunc="mean")
# Out:
#            Total day calls  Total eve calls  Total night calls
# Area code
# 408             100.496420        99.788783          99.039379
# 415             100.576435       100.503927         100.398187
# 510             100.097619        99.671429         100.601190

# %%
df.pivot_table(["Total day calls", "Total eve calls", "Total night calls"], ["State"], aggfunc="sum")
# Out:
#        Total day calls  Total eve calls  Total night calls
# State
# AK                4954             5022               5062
# AL                7928             7877               7889
# AR                5618             5381               5448
# AZ                6407             6554               6399
# CA                3553             3505               3373
# CO                6278             6479               6406
# CT                7284             7335               7569
# DC                5409             5507               5274
# DE                6017             5939               6174
# FL                6363             6862               6321
# GA                5565             5610               5693
# HI                5449             5239               5255
# IA                4534             4380               4406
# ID                7754             7304               7331
# IL                5898             5847               5755
# ...
